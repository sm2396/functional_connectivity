# %%
#import necessary programs
import numpy as np
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.signal import welch
from scipy.signal import coherence

# %% [markdown]
# # looking at day 5 data

# %%
#pre
psd_files_pre_day5 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day5_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day5_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day5_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day5_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day5_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day5_(4, 8)_psd_results_pre.npy'
]

psd_data_pre_day5 = [np.load(file) for file in psd_files_pre_day5]
print(psd_data_pre_day5)
# Out:
# [array([[3.86827455e-13, 3.42676180e-13, 3.37267330e-13, 4.20303363e-13,
#         4.20160455e-13, 4.53233221e-13, 4.24777838e-13, 4.46719332e-13,
#         3.99923439e-13, 3.51965096e-13, 3.10253507e-13, 4.48473114e-13,
#         4.29895056e-13, 4.24346408e-13, 4.23233261e-13, 4.09323895e-13,
#         3.60804783e-13, 3.35716527e-13, 3.48529194e-13, 4.64642432e-13,
#         4.35408372e-13, 3.83062926e-13, 3.73941850e-13, 3.31461345e-13,
#         2.82618849e-13, 3.17065448e-13, 3.66885116e-13, 3.63359191e-13,
#         3.49616393e-13, 3.31912409e-13, 2.95726048e-13, 3.31445225e-13,
#         3.32808854e-13, 3.24544159e-13, 3.49485396e-13, 3.26336440e-13,
#         3.13717498e-13, 3.57949089e-13, 3.30031569e-13, 3.13526622e-13,
#         2.82237702e-13, 2.80218415e-13, 2.35490317e-13, 2.42335715e-13,
#         3.28299783e-13, 4.27287306e-13, 4.09464845e-13, 3.67396154e-13,
#         3.03983878e-13, 2.22257488e-13, 1.58554969e-13, 1.69085294e-13,
# ...

# %%
# average PSD pre
average_psd_pre_day5 = np.mean(psd_data_pre_day5, axis=0)
#print(average_psd_pre_day5)
#print(average_psd_pre_day5.shape)
average_psd_pre_1d_day5 = average_psd_pre_day5.flatten()
#print(average_psd_pre_1d_day5.shape)

# standard deviation pre
std_dev_pre_day5 = np.std(np.concatenate(psd_data_pre_day5), ddof=1)
#print(std_dev_pre_day5)

plt.imshow(average_psd_pre_day5)
average_psd_pre_day5.shape
# Out:
# (1, 257)

# %%
average_psd_results_pre_day5 = []
# define  frequency band we will look at
freq_bands = [(4, 8)] # theta
#freq_bands = [(8, 12)]  #alpha
#freq_bands = [(13, 30)] #beta
#freq_bands = [(30, 50)] #gamma

for freq_band in freq_bands:
    fmin, fmax = freq_band
    f, psd = welch(average_psd_pre_day5.get_data(), fs=average_psd_pre_day5.info['sfreq'])
    freq_mask = (f >= fmin) & (f <= fmax)
    psd_band = psd[:, freq_mask].mean(axis=1)  # Calculate mean PSD in the frequency band
    average_psd_results_pre_day5.append(psd_band) # psd_results now contains the mean PSD for each specified frequency band
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/88/gj05zhtx4hb9gd7yts5kqdgr0000gn/T/ipykernel_32475/2587733648.py in <module>
#       8 for freq_band in freq_bands:
#       9     fmin, fmax = freq_band
# ---> 10     f, psd = welch(average_psd_pre_day5.get_data(), fs=average_psd_pre_day5.info['sfreq'])
#      11     freq_mask = (f >= fmin) & (f <= fmax)
#      12     psd_band = psd[:, freq_mask].mean(axis=1)  # Calculate mean PSD in the frequency band
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_data'

# %%
#post1
psd_files_post1_day5 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day5_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day5_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day5_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day5_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day5_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day5_(4, 8)_psd_results_post1.npy'
]

psd_data_post1_day5 = [np.load(file) for file in psd_files_post1_day5]
print(psd_data_post1_day5)

# %%
# average PSD post1
average_psd_post1_day5 = np.mean(psd_data_post1_day5, axis=0)
print(average_psd_post1_day5)
print(average_psd_post1_day5.shape)
average_psd_post1_1d_day5 = average_psd_post1_day5.flatten()
print(average_psd_post1_1d_day5.shape)

# standard deviation post1
std_dev_post1_day5 = np.std(np.concatenate(psd_data_post1_day5), ddof=1)
print(std_dev_post1_day5)

# %%
#post2
psd_files_post2_day5 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day5_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day5_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day5_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day5_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day5_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day5_(4, 8)_psd_results_post2.npy'
]

psd_data_post2_day5 = [np.load(file) for file in psd_files_post2_day5]
print(psd_data_post2_day5)

# %%
# average PSD post2
average_psd_post2_day5 = np.mean(psd_data_post2_day5, axis=0)
print(average_psd_post2_day5)
print(average_psd_post2_day5.shape)
average_psd_post2_1d_day5 = average_psd_post2_day5.flatten()
print(average_psd_post2_1d_day5.shape)

# standard deviation post2
std_dev_post2_day5 = np.std(np.concatenate(psd_data_post2_day5), ddof=1)
print(std_dev_post2_day5)

# %%
#post combined
psd_files_post_combined_day5 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day5_(4, 8)_psd_results_post_combined.npy'
]

psd_data_post_combined_day5 = [np.load(file) for file in psd_files_post_combined_day5]
print(psd_data_post_combined_day5)

# %%
# average PSD post_combined
average_psd_post_combined_day5 = np.mean(psd_data_post_combined_day5, axis=0)
print(average_psd_post_combined_day5)
print(average_psd_post_combined_day5.shape)
average_psd_post_combined_1d_day5 = average_psd_post_combined_day5.flatten()
print(average_psd_post_combined_1d_day5.shape)

# standard deviation post_combined
std_dev_post_combined_day5 = np.std(np.concatenate(psd_data_post_combined_day5), ddof=1)
print(std_dev_post_combined_day5)

# %%
#let's set up some t-tests
#pre and post 1
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day5, average_psd_post1_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day5, average_psd_post1_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#pre and post 2
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day5, average_psd_post2_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day5, average_psd_post2_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#pre and post_combined
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day5, average_psd_post_combined_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day5, average_psd_post_combined_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#post 1 and post 2 
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day5, average_psd_post2_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day5, average_psd_post2_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %% [markdown]
# # let's try day 3

# %%
#pre
psd_files_pre_day3 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day3_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day3_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day3_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day3_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day3_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day3_(4, 8)_psd_results_pre.npy'
]

psd_data_pre_day3 = [np.load(file) for file in psd_files_pre_day3]
print(psd_data_pre_day3)

#post1
psd_files_post1_day3 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day3_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day3_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day3_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day3_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day3_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day3_(4, 8)_psd_results_post1.npy'
]

psd_data_post1_day3 = [np.load(file) for file in psd_files_post1_day3]
print(psd_data_post1_day3)

#post2
psd_files_post2_day3 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day3_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day3_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day3_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day3_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day3_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day3/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day3_(4, 8)_psd_results_post2.npy'
]

psd_data_post2_day3 = [np.load(file) for file in psd_files_post2_day3]
print(psd_data_post2_day3)

#post combined
psd_files_post_combined_day3 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day5_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day5/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day5_(4, 8)_psd_results_post_combined.npy'
]

psd_data_post_combined_day3 = [np.load(file) for file in psd_files_post_combined_day3]
print(psd_data_post_combined_day3)

# %%
# average PSD pre
average_psd_pre_day3 = np.mean(psd_data_pre_day3, axis=0)
print(average_psd_pre_day3)
print(average_psd_pre_day3.shape)
average_psd_pre_1d_day3 = average_psd_pre_day3.flatten()
print(average_psd_pre_1d_day3.shape)

# standard deviation pre
std_dev_pre_day3 = np.std(np.concatenate(psd_data_pre_day3), ddof=1)
print(std_dev_pre_day3)

# average PSD post1
average_psd_post1_day3 = np.mean(psd_data_post1_day3, axis=0)
print(average_psd_post1_day3)
print(average_psd_post1_day3.shape)
average_psd_post1_1d_day3 = average_psd_post1_day3.flatten()
print(average_psd_post1_1d_day3.shape)

# standard deviation post1
std_dev_post1_day3 = np.std(np.concatenate(psd_data_post1_day3), ddof=1)
print(std_dev_post1_day3)

# average PSD post2
average_psd_post2_day3 = np.mean(psd_data_post2_day3, axis=0)
print(average_psd_post2_day3)
print(average_psd_post2_day3.shape)
average_psd_post2_1d_day3 = average_psd_post2_day3.flatten()
print(average_psd_post2_1d_day3.shape)

# standard deviation post2
std_dev_post2_day3 = np.std(np.concatenate(psd_data_post2_day3), ddof=1)
print(std_dev_post2_day3)

# average PSD post_combined
average_psd_post_combined_day3 = np.mean(psd_data_post_combined_day3, axis=0)
print(average_psd_post_combined_day3)
print(average_psd_post_combined_day3.shape)
average_psd_post_combined_1d_day3 = average_psd_post_combined_day3.flatten()
print(average_psd_post_combined_1d_day3.shape)

# standard deviation post_combined
std_dev_post_combined_day3 = np.std(np.concatenate(psd_data_post_combined_day3), ddof=1)
print(std_dev_post_combined_day3)

# %%
#let's set up some t-tests
#pre and post 1
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day3, average_psd_post1_1d_day3)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day3, average_psd_post1_1d_day3, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

#pre and post 2
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day3, average_psd_post2_1d_day3)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day3, average_psd_post2_1d_day3, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

#pre and post_combined
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day3, average_psd_post_combined_1d_day3)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day3, average_psd_post_combined_1d_day3, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")
    
#post 1 and post 2 
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day3, average_psd_post2_1d_day3)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day3, average_psd_post2_1d_day3, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %% [markdown]
# # maybe day 1?

# %%
#pre
psd_files_pre_day1 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day1_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day1_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day1_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day1_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day1_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day1_(4, 8)_psd_results_pre.npy'
]

psd_data_pre_day1 = [np.load(file) for file in psd_files_pre_day1]
print(psd_data_pre_day1)

#post1
psd_files_post1_day1 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day1_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day1_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day1_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day1_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day1_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day1_(4, 8)_psd_results_post1.npy'
]

psd_data_post1_day1 = [np.load(file) for file in psd_files_post1_day1]
print(psd_data_post1_day1)

#post2
psd_files_post2_day1 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day1_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day1_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day1_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day1_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day1_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day1_(4, 8)_psd_results_post2.npy'
]

psd_data_post2_day1 = [np.load(file) for file in psd_files_post2_day1]
print(psd_data_post2_day1)

#post combined
psd_files_post_combined_day1 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day1_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day1_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day1_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day1_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day1_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day1/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day1_(4, 8)_psd_results_post_combined.npy'
]

psd_data_post_combined_day1 = [np.load(file) for file in psd_files_post_combined_day1]
print(psd_data_post_combined_day1)

# %%
# average PSD pre
average_psd_pre_day1 = np.mean(psd_data_pre_day1, axis=0)
print(average_psd_pre_day1)
print(average_psd_pre_day1.shape)
average_psd_pre_1d_day1 = average_psd_pre_day1.flatten()
print(average_psd_pre_1d_day1.shape)

# standard deviation pre
std_dev_pre_day1 = np.std(np.concatenate(psd_data_pre_day1), ddof=1)
print(std_dev_pre_day1)

# average PSD post1
average_psd_post1_day1 = np.mean(psd_data_post1_day1, axis=0)
print(average_psd_post1_day1)
print(average_psd_post1_day1.shape)
average_psd_post1_1d_day1 = average_psd_post1_day1.flatten()
print(average_psd_post1_1d_day1.shape)

# standard deviation post1
std_dev_post1_day1 = np.std(np.concatenate(psd_data_post1_day1), ddof=1)
print(std_dev_post1_day1)

# average PSD post2
average_psd_post2_day1 = np.mean(psd_data_post2_day1, axis=0)
print(average_psd_post2_day1)
print(average_psd_post2_day1.shape)
average_psd_post2_1d_day1 = average_psd_post2_day1.flatten()
print(average_psd_post2_1d_day1.shape)

# standard deviation post2
std_dev_post2_day1 = np.std(np.concatenate(psd_data_post2_day1), ddof=1)
print(std_dev_post2_day1)

# average PSD post_combined
average_psd_post_combined_day1 = np.mean(psd_data_post_combined_day1, axis=0)
print(average_psd_post_combined_day1)
print(average_psd_post_combined_day1.shape)
average_psd_post_combined_1d_day1 = average_psd_post_combined_day1.flatten()
print(average_psd_post_combined_1d_day1.shape)

# standard deviation post_combined
std_dev_post_combined_day1 = np.std(np.concatenate(psd_data_post_combined_day1), ddof=1)
print(std_dev_post_combined_day1)

# %%
#let's set up some t-tests
#pre and post 1
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_post1_1d_day1)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_post1_1d_day1, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

#pre and post 2
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_post2_1d_day1)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_post2_1d_day1, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

#pre and post_combined
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_post_combined_1d_day1)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day1, average_psd_post_combined_1d_day1, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")
    
#post 1 and post 2 
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day1, average_psd_post2_1d_day1)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day1, average_psd_post2_1d_day1, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %% [markdown]
# # day 2 for sure

# %%
#pre
psd_files_pre_day2 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day2_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day2_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day2_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day2_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day2_(4, 8)_psd_results_pre.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day2_(4, 8)_psd_results_pre.npy'
]

psd_data_pre_day2 = [np.load(file) for file in psd_files_pre_day2]
print(psd_data_pre_day2)

#post1
psd_files_post1_day2 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day2_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day2_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day2_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day2_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day2_(4, 8)_psd_results_post1.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day2_(4, 8)_psd_results_post1.npy'
]

psd_data_post1_day2 = [np.load(file) for file in psd_files_post1_day2]
print(psd_data_post1_day2)

#post2
psd_files_post2_day2 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day2_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day2_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day2_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day2_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day2_(4, 8)_psd_results_post2.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day2_(4, 8)_psd_results_post2.npy'
]

psd_data_post2_day2 = [np.load(file) for file in psd_files_post2_day2]
print(psd_data_post2_day2)

#post combined
psd_files_post_combined_day2 = [
    '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day2_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day2_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day2_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day2_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day2_(4, 8)_psd_results_post_combined.npy',
    '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day2/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day2_(4, 8)_psd_results_post_combined.npy'
]

psd_data_post_combined_day2 = [np.load(file) for file in psd_files_post_combined_day2]
print(psd_data_post_combined_day2)

# %%
# average PSD pre
average_psd_pre_day2 = np.mean(psd_data_pre_day2, axis=0)
print(average_psd_pre_day2)
print(average_psd_pre_day2.shape)
average_psd_pre_1d_day2 = average_psd_pre_day2.flatten()
print(average_psd_pre_1d_day2.shape)

# standard deviation pre
std_dev_pre_day2 = np.std(np.concatenate(psd_data_pre_day2), ddof=1)
print(std_dev_pre_day2)

# average PSD post1
average_psd_post1_day2 = np.mean(psd_data_post1_day2, axis=0)
print(average_psd_post1_day2)
print(average_psd_post1_day2.shape)
average_psd_post1_1d_day2 = average_psd_post1_day2.flatten()
print(average_psd_post1_1d_day2.shape)

# standard deviation post1
std_dev_post1_day2 = np.std(np.concatenate(psd_data_post1_day2), ddof=1)
print(std_dev_post1_day2)

# average PSD post2
average_psd_post2_day2 = np.mean(psd_data_post2_day2, axis=0)
print(average_psd_post2_day2)
print(average_psd_post2_day2.shape)
average_psd_post2_1d_day2 = average_psd_post2_day2.flatten()
print(average_psd_post2_1d_day2.shape)

# standard deviation post2
std_dev_post2_day2 = np.std(np.concatenate(psd_data_post2_day2), ddof=1)
print(std_dev_post2_day2)

# average PSD post_combined
average_psd_post_combined_day2 = np.mean(psd_data_post_combined_day2, axis=0)
print(average_psd_post_combined_day2)
print(average_psd_post_combined_day2.shape)
average_psd_post_combined_1d_day2 = average_psd_post_combined_day2.flatten()
print(average_psd_post_combined_1d_day2.shape)

# standard deviation post_combined
std_dev_post_combined_day2 = np.std(np.concatenate(psd_data_post_combined_day2), ddof=1)
print(std_dev_post_combined_day2)

# %%
#let's set up some t-tests
#pre and post 1
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day2, average_psd_post1_1d_day2)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day2, average_psd_post1_1d_day2, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

#pre and post 2
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day2, average_psd_post2_1d_day2)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day2, average_psd_post2_1d_day2, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

#pre and post_combined
#regular t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day2, average_psd_post_combined_1d_day2)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day2, average_psd_post_combined_1d_day2, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")
    
#post 1 and post 2 
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day2, average_psd_post2_1d_day2)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day2, average_psd_post2_1d_day2, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %% [markdown]
# # day 4

# %% [markdown]
# #pre
# psd_files_pre_day4 = [
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day4_(4, 8)_psd_results_pre.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day4_(4, 8)_psd_results_pre.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day4_(4, 8)_psd_results_pre.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day4_(4, 8)_psd_results_pre.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day4_(4, 8)_psd_results_pre.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day4_(4, 8)_psd_results_pre.npy'
# ]
#
# psd_data_pre_day4 = [np.load(file) for file in psd_files_pre_day4]
# print(psd_data_pre_day4)
#
# #post1
# psd_files_post1_day4 = [
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day4_(4, 8)_psd_results_post1.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day4_(4, 8)_psd_results_post1.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day4_(4, 8)_psd_results_post1.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day4_(4, 8)_psd_results_post1.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day4_(4, 8)_psd_results_post1.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day4_(4, 8)_psd_results_post1.npy'
# ]
#
# psd_data_post1_day4 = [np.load(file) for file in psd_files_post1_day4]
# print(psd_data_post1_day4)
#
# #post2
# psd_files_post2_day4 = [
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day4_(4, 8)_psd_results_post2.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day4_(4, 8)_psd_results_post2.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day4_(4, 8)_psd_results_post2.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day4_(4, 8)_psd_results_post2.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day4_(4, 8)_psd_results_post2.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day4_(4, 8)_psd_results_post2.npy'
# ]
#
# psd_data_post2_day4 = [np.load(file) for file in psd_files_post2_day4]
# print(psd_data_post2_day4)
#
# #post combined
# psd_files_post_combined_day4 = [
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject3_m159_dlpfc_57/m159_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m159_dlpfc_day4_(4, 8)_psd_results_post_combined.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject5_m155_dlpfc_58/m155_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m155_dlpfc_day4_(4, 8)_psd_results_post_combined.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject6_m160_dlpfc_57/m160_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m160_dlpfc_day4_(4, 8)_psd_results_post_combined.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject7_m144_dlpfc_54/m144_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m144_dlpfc_day4_(4, 8)_psd_results_post_combined.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject9_m191_dlpfc_58/m191_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m191_dlpfc_day4_(4, 8)_psd_results_post_combined.npy',
#     '/Users/sanwedamahagabin/Desktop/patient_data/subject21_m275_dlpfc_59/m275_dlpfc_day4/Results/results_run_000/split_fif/psd_results/m275_dlpfc_day4_(4, 8)_psd_results_post_combined.npy'
# ]
#
# psd_data_post_combined_day4 = [np.load(file) for file in psd_files_post_combined_day4]
# print(psd_data_post_combined_day4)

# %% [markdown]
# # average PSD pre
# average_psd_pre_day4 = np.mean(psd_data_pre_day4, axis=0)
# print(average_psd_pre_day4)
# print(average_psd_pre_day4.shape)
# average_psd_pre_1d_day4 = average_psd_pre_day4.flatten()
# print(average_psd_pre_1d_day4.shape)
#
# # standard deviation pre
# std_dev_pre_day4 = np.std(np.concatenate(psd_data_pre_day4), ddof=1)
# print(std_dev_pre_day4)
#
# # average PSD post1
# average_psd_post1_day4 = np.mean(psd_data_post1_day4, axis=0)
# print(average_psd_post1_day4)
# print(average_psd_post1_day4.shape)
# average_psd_post1_1d_day4 = average_psd_post1_day4.flatten()
# print(average_psd_post1_1d_day4.shape)
#
# # standard deviation post1
# std_dev_post1_day4 = np.std(np.concatenate(psd_data_post1_day4), ddof=1)
# print(std_dev_post1_day4)
#
# # average PSD post2
# average_psd_post2_day4 = np.mean(psd_data_post2_day4, axis=0)
# print(average_psd_post2_day4)
# print(average_psd_post2_day4.shape)
# average_psd_post2_1d_day4 = average_psd_post2_day4.flatten()
# print(average_psd_post2_1d_day4.shape)
#
# # standard deviation post2
# std_dev_post2_day4 = np.std(np.concatenate(psd_data_post2_day4), ddof=1)
# print(std_dev_post2_day4)
#
# # average PSD post_combined
# average_psd_post_combined_day4 = np.mean(psd_data_post_combined_day4, axis=0)
# print(average_psd_post_combined_day4)
# print(average_psd_post_combined_day4.shape)
# average_psd_post_combined_1d_day4 = average_psd_post_combined_day4.flatten()
# print(average_psd_post_combined_1d_day4.shape)
#
# # standard deviation post_combined
# std_dev_post_combined_day4 = np.std(np.concatenate(psd_data_post_combined_day4), ddof=1)
# print(std_dev_post_combined_day4)

# %% [markdown]
# #let's set up some t-tests
# #pre and post 1
# #regular t-test
# t_statistic, p_value = ttest_ind(average_psd_pre_1d_day4, average_psd_post1_1d_day4)
# alpha = 0.05  #significance value
# if p_value < alpha:
#     print("The difference is statistically significant (reject null hypothesis)")
# else:
#     print("The difference is not statistically significant (fail to reject null hypothesis)")
# #pooled t-test
# t_statistic, p_value = ttest_ind(average_psd_pre_1d_day4, average_psd_post1_1d_day4, equal_var=True)
# print(f"T-statistic: {t_statistic}")
# print(f"P-value: {p_value}")
# if p_value < 0.05: #significance check
#     print("The difference is statistically significant.")
# else:
#     print("The difference is not statistically significant.")
#
# #pre and post 2
# #regular t-test
# t_statistic, p_value = ttest_ind(average_psd_pre_1d_day4, average_psd_post2_1d_day4)
# alpha = 0.05  #significance value
# if p_value < alpha:
#     print("The difference is statistically significant (reject null hypothesis)")
# else:
#     print("The difference is not statistically significant (fail to reject null hypothesis)")
# #pooled t-test
# t_statistic, p_value = ttest_ind(average_psd_pre_1d_day4, average_psd_post2_1d_day4, equal_var=True)
# print(f"T-statistic: {t_statistic}")
# print(f"P-value: {p_value}")
# if p_value < 0.05: #significance check
#     print("The difference is statistically significant.")
# else:
#     print("The difference is not statistically significant.")
#
# #pre and post_combined
# #regular t-test
# t_statistic, p_value = ttest_ind(average_psd_pre_1d_day4, average_psd_post_combined_1d_day4)
# alpha = 0.05  #significance value
# if p_value < alpha:
#     print("The difference is statistically significant (reject null hypothesis)")
# else:
#     print("The difference is not statistically significant (fail to reject null hypothesis)")
# #pooled t-test
# t_statistic, p_value = ttest_ind(average_psd_post1_1d_day4, average_psd_post_combined_1d_day4, equal_var=True)
# print(f"T-statistic: {t_statistic}")
# print(f"P-value: {p_value}")
# if p_value < 0.05: #significance check
#     print("The difference is statistically significant.")
# else:
#     print("The difference is not statistically significant.")
#
# #post 1 and post 2
# t_statistic, p_value = ttest_ind(average_psd_post1_1d_day4, average_psd_post2_1d_day4)
# alpha = 0.05  #significance value
# if p_value < alpha:
#     print("The difference is statistically significant (reject null hypothesis)")
# else:
#     print("The difference is not statistically significant (fail to reject null hypothesis)")
# #pooled t-test
# t_statistic, p_value = ttest_ind(average_psd_post1_1d_day4, average_psd_post2_1d_day4, equal_var=True)
# print(f"T-statistic: {t_statistic}")
# print(f"P-value: {p_value}")
# if p_value < 0.05: #significance check
#     print("The difference is statistically significant.")
# else:
#     print("The difference is not statistically significant.")

# %% [markdown]
# # t-tests between days

# %%
#t-test between day 1 and day 5
t_test_matrix = np.zeros(average_psd_pre_day5.shape)

epsilon = 1e-10

# Perform t-test for each pair of values
for i in range(average_psd_pre_day5.shape[1]):
    t_statistic, _ = ttest_ind(average_psd_pre_day1[:, i]+epsilon, average_psd_pre_day5[:, i]+epsilon)
    t_test_matrix[0, i] = t_statistic

print(t_test_matrix)

# %%
#day 1 and day 5 pre
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_pre_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_pre_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#day 1 and day 5 post1
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day1, average_psd_post1_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day1, average_psd_post1_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#day 1 and day 5 post2
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_post2_1d_day1, average_psd_post2_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post2_1d_day1, average_psd_post2_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#day 1 and day 3 pre
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_pre_1d_day3)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day1, average_psd_pre_1d_day3, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#day 1 and day 3 post1
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day1, average_psd_post1_1d_day3)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day1, average_psd_post1_1d_day3, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#day 1 and day 3 post2
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_post2_1d_day1, average_psd_post2_1d_day3)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post2_1d_day1, average_psd_post2_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#day 3 and day 5 pre
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day3, average_psd_pre_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_pre_1d_day3, average_psd_pre_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#day 3 and day 5 post1
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day3, average_psd_post1_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day3, average_psd_post1_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# %%
#day 3 and day 5 post2
#regular t-test 
t_statistic, p_value = ttest_ind(average_psd_post2_1d_day3, average_psd_post2_1d_day5)
alpha = 0.05  #significance value
if p_value < alpha:
    print("The difference is statistically significant (reject null hypothesis)")
else:
    print("The difference is not statistically significant (fail to reject null hypothesis)")
#pooled t-test
t_statistic, p_value = ttest_ind(average_psd_post1_1d_day3, average_psd_post1_1d_day5, equal_var=True)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
if p_value < 0.05: #significance check
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")
